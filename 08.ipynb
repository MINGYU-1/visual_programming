# %%
width = 10
precision = 4
value = 12.34567
# f"result:{value:{width}.{precision}f}"
f"result:{value:10.3f}"
f"int:{42:d}"
# Out:
# 'result:    12.346'

# %%
file = open('my_file.txt','w')
file.write('드디어 쓸모 있어보이는걸 배운다.\n')
file.close()
file = open('my_file.txt','a')
file.write('드디어 쓸모있어보이는걸 배우나?\n')
file.close()

# %%
file = open('my_file.txt','a')
file.write('드디어 쓸모 있어보이는걸 배운다.\n')
file.close()
file = open('my_file.txt','r')
file.readlines()
# Out:
# ['드디어 쓸모 있어보이는걸 배운다.\n', '드디어 쓸모 있어보이는걸 배운다.\n']

# %%
with open('my_file.txt','r') as file:
    print(file.readlines())
# Out:
# ['드디어 쓸모 있어보이는걸 배운다.\n', '드디어 쓸모 있어보이는걸 배운다.\n']

# %%
f"result:{12.4242554:f}"
# Out:
# 'result:12.424255'

# %%
points = 19
total = 22
accuracy = points / total
"Correct Answers: {:.2f}".format(accuracy)
"Correct answers: {:*>10.2f}".format(accuracy)
# Out:
# 'Correct answers: ******0.86'

# %%
# 파일이란?
## 운영체제(OS)에서 정보를 저장하기 위한 논리적 단위
# 파일의 구조는?
# 알필요 없다
f"{'left algin':<30}"
# Out:
# 'left algin                    '

# %%
## 예제1
with open('test.txt','w') as file:
    file.write('Hello world\n')
with open('test.txt','r') as file:
    print(file.readline())
with open('test.txt','a') as file:
    file.write('return\n')
with open('test.txt','r') as file:
    read_data = file.readline()
    while read_data != '':
        print(read_data,end = ' ')
        read_data = file.readline()

# %%
## 예제 2
matrix = [[1,2,3],[4,5,6],[7,8,9]]
with open('test.csv','w') as file:
    for row in matrix:
        file.write(f'{row[0]},{row[1]},{row[2]}\n')

with open('test.csv','r') as file:
    read_data = file.readline()
    while read_data != '':
        print(read_data, end = '')
        read_data = file.readline()
# Out:
# 1,2,3
# 4,5,6
# 7,8,9

# %%
## 예제 3
matrix = []

# %%
# for token in text
file = open('hamlet.txt')
f'{key}:{value}\n' # 불용어 처리에 관한 것에 대해서 없애서 사용할 수 있다. ㄴ
# 소문자 대문자는 upper나 lower와 같은 매소드를 사용해서 구한다.
